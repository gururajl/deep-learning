# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6608 0.1607 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6244 0.0291 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5190 0.0293 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5679 0.0290 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4864 0.0292 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5002 0.0290 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5403 0.0293 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5437 0.0291 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4682 0.0290 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4255 0.0289 sec/batch
# Nearest to between: inquisitors, arterial, bellies, amputee, parades, embarrassing, contends, covey,
# Nearest to at: apostate, monopolization, eas, lindy, seedlings, cropped, stakeholders, thurston,
# Nearest to into: from, forgiving, debrecen, jamiroquai, ages, blu, yoreh, vanish,
# Nearest to has: ashes, brownstone, surfaces, hetero, peralta, resolution, iv, pon,
# Nearest to but: anno, healthier, foreigners, atonement, naming, sotho, inprise, ncv,
# Nearest to not: bloodedness, cello, socially, morning, institut, dismissing, cosmography, montessori,
# Nearest to d: nive, brightness, hicks, vechten, koyaanisqatsi, caricatured, belli, bali,
# Nearest to he: nike, cosmological, shell, saddle, grip, grantley, penicillin, dsm,
# Nearest to nobel: trouv, abodes, adhemar, daimlerchrysler, isomorphisms, prokaryotic, sgh, lymphocyte,
# Nearest to event: harker, polypropylene, tonight, eroded, historique, nix, enforces, parrot,
# Nearest to dr: cooh, feb, forbidding, scholes, disruptive, propto, emerged, certifications,
# Nearest to lived: flo, sintered, nye, accent, fainter, cheapest, exptime, crests,
# Nearest to rise: mcgowan, myung, cvbgs, barre, hacienda, agates, mismanaged, pretends,
# Nearest to arts: slew, concatenation, saccas, imposition, acting, coffey, neurone, subtler,
# Nearest to shown: troas, thrown, wcs, naissus, kda, zone, gir, minesweeper,
# Nearest to account: reprisals, tars, automaticity, formulaic, gunboat, taxa, affirm, mansur,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4950 0.0300 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3597 0.0290 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3364 0.0290 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2408 0.0290 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2097 0.0291 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1699 0.0290 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0759 0.0288 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0906 0.0290 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0153 0.0290 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9598 0.0291 sec/batch
# Nearest to between: inquisitors, contends, arterial, ambiguity, unless, stages, bellies, national,
# Nearest to at: apostate, dealing, often, stakeholders, lindy, efficient, thurston, power,
# Nearest to into: from, ages, jamiroquai, demographic, blu, forgiving, excluded, bourgeois,
# Nearest to has: surfaces, view, iv, actors, ashes, different, west, resolution,
# Nearest to but: naming, foreigners, anno, healthier, ultimate, wasn, atonement, sets,
# Nearest to not: order, morning, socially, cello, machine, dismissing, tokens, contributors,
# Nearest to d: brightness, nive, hicks, formed, belli, temple, unenforceable, helping,
# Nearest to he: cosmological, grip, nike, shell, dsm, saddle, penicillin, grantley,
# Nearest to nobel: trouv, abodes, prokaryotic, sgh, daimlerchrysler, isomorphisms, mo, sanctioned,
# Nearest to event: tonight, harker, violence, eroded, ranked, enforces, sunday, polypropylene,
# Nearest to dr: cooh, forbidding, feb, emerged, disruptive, certifications, indices, nonfiction,
# Nearest to lived: accent, emerged, backed, money, flo, hang, formally, separated,
# Nearest to rise: french, feet, prevalent, mcgowan, moving, notion, mismanaged, duke,
# Nearest to arts: slew, acting, modern, consequently, saccas, subtler, lane, which,
# Nearest to shown: thrown, zone, troas, wcs, systems, kda, symmetric, naissus,
# Nearest to account: reprisals, automaticity, formulaic, tars, taxa, gunboat, become, bordered,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9155 0.0301 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8996 0.0290 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8831 0.0288 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8696 0.0294 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8223 0.0290 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8099 0.0289 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7784 0.0291 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7855 0.0291 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8017 0.0291 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7764 0.0290 sec/batch
# Nearest to between: arterial, inquisitors, contends, ambiguity, parades, unless, hereditary, bellies,
# Nearest to at: apostate, nineteen, outlets, dealing, hysteria, masks, efficient, outflow,
# Nearest to into: from, blu, ages, demographic, debrecen, forgiving, sketch, detail,
# Nearest to has: surfaces, ashes, actors, resolution, westphalia, brownstone, luigi, iv,
# Nearest to but: foreigners, naming, healthier, ultimate, wasn, anno, scanner, atonement,
# Nearest to not: morning, contributors, order, eclectic, socially, cello, generalizations, positioned,
# Nearest to d: brightness, restoring, nokia, vechten, nive, hicks, tra, belli,
# Nearest to he: cosmological, saddle, shell, nike, dsm, grip, penicillin, nightmare,
# Nearest to nobel: isomorphisms, trouv, abodes, prokaryotic, sgh, poet, daimlerchrysler, scribner,
# Nearest to event: harker, sunday, tonight, violence, ranked, eroded, enforces, parrot,
# Nearest to dr: cooh, feb, forbidding, disruptive, emerged, auguste, certifications, collaborators,
# Nearest to lived: emerged, accent, nye, lord, sintered, flo, backed, hang,
# Nearest to rise: french, mcgowan, feet, prevalent, myung, barre, superluminal, transmissions,
# Nearest to arts: slew, modern, acting, consequently, lane, exploits, saccas, contestants,
# Nearest to shown: thrown, troas, wcs, zone, naissus, symmetric, kda, systems,
# Nearest to account: reprisals, formulaic, tars, automaticity, affirm, taxa, gunboat, become,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7740 0.0302 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7763 0.0289 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7189 0.0291 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7059 0.0290 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7249 0.0293 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6763 0.0290 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7329 0.0290 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7089 0.0289 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7043 0.0291 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6686 0.0288 sec/batch
# Nearest to between: inquisitors, arterial, contends, parades, ambiguity, unless, amputee, embarrassing,
# Nearest to at: apostate, outlets, masks, nineteen, hysteria, civilians, lindy, stakeholders,
# Nearest to into: blu, from, ages, debrecen, odo, forgiving, demographic, vanish,
# Nearest to has: ashes, brownstone, surfaces, resolution, actors, jail, hetero, pon,
# Nearest to but: healthier, foreigners, anno, wasn, ultimate, naming, scanner, si,
# Nearest to not: contributors, bloodedness, order, eclectic, morning, positioned, adapt, generalizations,
# Nearest to d: painter, vechten, nokia, restoring, tra, belli, recipient, bali,
# Nearest to he: saddle, cosmological, derrick, shell, nike, dsm, nightmare, banishment,
# Nearest to nobel: poet, one, isomorphisms, trouv, sgh, abodes, zarqa, enacts,
# Nearest to event: harker, sunday, ranked, tonight, violence, eroded, parrot, enforces,
# Nearest to dr: feb, cooh, forbidding, disruptive, auguste, fielders, emerged, certifications,
# Nearest to lived: emerged, flo, lord, nye, fainter, accent, cheapest, backed,
# Nearest to rise: french, myung, mcgowan, barre, feet, superluminal, canidae, saudi,
# Nearest to arts: modern, slew, acting, consequently, lane, subtler, exploits, saccas,
# Nearest to shown: thrown, troas, wcs, symmetric, kda, naissus, zone, gir,
# Nearest to account: reprisals, tars, affirm, formulaic, gunboat, automaticity, taxa, christie,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6643 0.0300 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6698 0.0290 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6074 0.0289 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6577 0.0290 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6427 0.0294 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6135 0.0290 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5988 0.0221 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5561 0.0290 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5141 0.0291 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5077 0.0290 sec/batch
# Nearest to between: inquisitors, arterial, contends, parades, unless, amputee, ambiguity, extend,
# Nearest to at: apostate, masks, outflow, civilians, hysteria, outlets, nineteen, lindy,
# Nearest to into: from, blu, ages, debrecen, yoreh, cordell, excluded, demographic,
# Nearest to has: brownstone, surfaces, pon, resolution, hetero, euboea, ashes, actors,
# Nearest to but: healthier, foreigners, ultimate, anno, wasn, pipes, sotho, scanner,
# Nearest to not: order, contributors, socially, adapt, generalizations, bloodedness, eclectic, positioned,
# Nearest to d: painter, poet, recipient, composer, laureate, writer, journalist, tra,
# Nearest to he: saddle, derrick, cosmological, banishment, mandalay, dead, nightmare, callejas,
# Nearest to nobel: poet, one, recipient, sgh, painter, nine, isomorphisms, lymphocyte,
# Nearest to event: harker, tonight, laden, eroded, violence, ranked, sunday, parrot,
# Nearest to dr: feb, cooh, forbidding, disruptive, fielders, auguste, scholes, emerged,
# Nearest to lived: emerged, flo, exptime, lord, fainter, cheapest, nye, sintered,
# Nearest to rise: mcgowan, myung, french, barre, superluminal, mismanaged, pretends, canidae,
# Nearest to arts: modern, slew, lane, acting, subtler, whitehaven, consequently, exploits,
# Nearest to shown: wcs, troas, thrown, kda, symmetric, minesweeper, gir, mogens,
# Nearest to account: reprisals, tars, affirm, formulaic, automaticity, mummification, gunboat, pragmatists,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4855 0.0301 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5078 0.0291 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4942 0.0291 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5204 0.0289 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4974 0.0292 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5039 0.0293 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4591 0.0288 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4047 0.0289 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4482 0.0290 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4269 0.0289 sec/batch
# Nearest to between: inquisitors, arterial, extend, contends, unless, parades, amputee, ambiguity,
# Nearest to at: outflow, hysteria, apostate, nineteen, lindy, cropped, outlets, civilians,
# Nearest to into: from, ages, blu, frente, yoreh, demographic, cordell, debrecen,
# Nearest to has: brownstone, surfaces, resolution, hetero, euboea, harms, pon, jail,
# Nearest to but: healthier, ultimate, foreigners, anno, wasn, sotho, way, worldwide,
# Nearest to not: order, adapt, socially, contributors, generalizations, tokens, severity, bloodedness,
# Nearest to d: painter, vechten, journalist, recipient, hicks, tra, laureate, poet,
# Nearest to he: mandalay, dead, saddle, banishment, derrick, cosmological, juba, callejas,
# Nearest to nobel: poet, one, sgh, recipient, painter, lymphocyte, isomorphisms, getz,
# Nearest to event: harker, tonight, laden, violence, sunday, polypropylene, parrot, eroded,
# Nearest to dr: feb, cooh, forbidding, fielders, emerged, disruptive, auguste, krak,
# Nearest to lived: exptime, emerged, fainter, lord, cheapest, flo, accent, houses,
# Nearest to rise: myung, mcgowan, barre, pretends, superluminal, mismanaged, french, stakeholder,
# Nearest to arts: modern, slew, subtler, lane, acting, whitehaven, wyman, curly,
# Nearest to shown: wcs, symmetric, kda, troas, thrown, baran, minesweeper, gir,
# Nearest to account: reprisals, tars, affirm, mansur, formulaic, automaticity, gunboat, pragmatists,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4568 0.0300 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4233 0.0289 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4410 0.0291 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4005 0.0290 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4204 0.0291 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4323 0.0291 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3865 0.0290 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3850 0.0289 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4112 0.0290 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3634 0.0291 sec/batch
# Nearest to between: inquisitors, arterial, extend, amputee, contends, unless, ambiguity, parades,
# Nearest to at: outflow, lindy, cropped, hysteria, apostate, photovoltaic, nineteen, masks,
# Nearest to into: from, ages, blu, yoreh, frente, debrecen, cordell, clot,
# Nearest to has: brownstone, hetero, euboea, surfaces, resolution, crm, carotenoids, harms,
# Nearest to but: healthier, ultimate, foreigners, wasn, anno, worldwide, sotho, pipes,
# Nearest to not: order, generalizations, tokens, adapt, socially, severity, contributors, particulars,
# Nearest to d: painter, vechten, laureate, hicks, recipient, composer, journalist, nokia,
# Nearest to he: juba, dead, mandalay, banishment, incorruptible, nightmare, his, derrick,
# Nearest to nobel: poet, one, sgh, recipient, trouv, painter, isomorphisms, getz,
# Nearest to event: tonight, harker, violence, parrot, polypropylene, sunday, enforces, bunge,
# Nearest to dr: feb, auguste, cooh, palais, fanon, emerged, krak, fielders,
# Nearest to lived: exptime, lord, emerged, fainter, flo, attalus, neue, nye,
# Nearest to rise: pretends, superluminal, myung, mismanaged, mcgowan, barre, canidae, maura,
# Nearest to arts: modern, lane, subtler, acting, slew, whitehaven, wyman, kata,
# Nearest to shown: wcs, symmetric, kda, troas, baran, thrown, mogens, needing,
# Nearest to account: reprisals, affirm, tars, mansur, automaticity, formulaic, pragmatists, gunboat,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3549 0.0299 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3953 0.0290 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3456 0.0291 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3517 0.0290 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3914 0.0289 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3816 0.0291 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3657 0.0292 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3728 0.0290 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3211 0.0290 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3427 0.0289 sec/batch
# Nearest to between: extend, arterial, inquisitors, amputee, contends, unless, ambiguity, embarrassing,
# Nearest to at: outflow, cropped, lindy, hysteria, apostate, outlets, nineteen, civilians,
# Nearest to into: from, frente, blu, yoreh, ages, lax, clot, cordell,
# Nearest to has: brownstone, hetero, resolution, surfaces, crm, harms, carotenoids, absorbance,
# Nearest to but: healthier, ultimate, wasn, foreigners, brought, recognize, eurosceptics, way,
# Nearest to not: generalizations, order, socially, adapt, tokens, severity, contributors, clarifies,
# Nearest to d: painter, vechten, hicks, laureate, recipient, composer, nokia, belli,
# Nearest to he: incorruptible, juba, his, dead, mandalay, derrick, callejas, spearman,
# Nearest to nobel: poet, sgh, one, recipient, cooper, blondes, getz, sonia,
# Nearest to event: tonight, harker, violence, parrot, sunday, polypropylene, unfair, revolts,
# Nearest to dr: feb, auguste, cooh, palais, fanon, krak, fielders, drinking,
# Nearest to lived: exptime, lord, emerged, fainter, attalus, orsz, flo, neue,
# Nearest to rise: superluminal, barre, myung, pretends, hacienda, canidae, mismanaged, chests,
# Nearest to arts: modern, painting, lane, subtler, art, whitehaven, kata, school,
# Nearest to shown: wcs, troas, baran, kda, symmetric, thrown, gir, mogens,
# Nearest to account: reprisals, affirm, tars, automaticity, formulaic, pragmatists, titus, mansur,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3405 0.0302 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2795 0.0292 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3799 0.0291 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3767 0.0291 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4038 0.0289 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2911 0.0290 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3041 0.0288 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3484 0.0288 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2526 0.0290 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2906 0.0291 sec/batch
# Nearest to between: extend, arterial, inquisitors, amputee, soteriology, contends, slovenians, unless,
# Nearest to at: outflow, lindy, cropped, hysteria, apostate, civilians, upstate, nineteen,
# Nearest to into: from, frente, yoreh, lax, ages, blu, cordell, clot,
# Nearest to has: brownstone, hetero, crm, resolution, hmac, pon, harms, mohawk,
# Nearest to but: healthier, ultimate, wasn, brought, evident, recognize, gaia, baudelaire,
# Nearest to not: generalizations, socially, order, severity, adapt, contributors, clarifies, particulars,
# Nearest to d: painter, vechten, laureate, hicks, composer, recipient, belli, illustrator,
# Nearest to he: incorruptible, herself, callejas, talking, spearman, his, formulation, juba,
# Nearest to nobel: one, poet, recipient, sgh, geneticist, heinrich, getz, prize,
# Nearest to event: tonight, harker, parrot, violence, christiansen, sunday, bronte, anthropology,
# Nearest to dr: feb, auguste, fanon, palais, cooh, scholes, fielders, novella,
# Nearest to lived: exptime, emerged, fainter, attalus, lord, flo, orsz, nye,
# Nearest to rise: superluminal, barre, hacienda, myung, canidae, chests, maura, mismanaged,
# Nearest to arts: modern, painting, subtler, kata, school, art, lane, architecture,
# Nearest to shown: wcs, troas, baran, symmetric, kda, naissus, runes, gir,
# Nearest to account: reprisals, tars, affirm, formulaic, mansur, automaticity, titus, pragmatists,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3214 0.0301 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2922 0.0289 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3142 0.0144 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2588 0.0289 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2458 0.0290 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2387 0.0291 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2085 0.0290 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2333 0.0290 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2251 0.0290 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1606 0.0290 sec/batch
# Nearest to between: extend, inquisitors, arterial, which, slovenians, eco, submissive, contends,
# Nearest to at: outflow, lindy, cropped, upstate, civilians, hysteria, profiles, apostate,
# Nearest to into: from, frente, yoreh, lax, ages, cordell, clot, stijl,
# Nearest to has: brownstone, pon, crm, hetero, resolution, hmac, harms, absorbance,
# Nearest to but: healthier, ultimate, wasn, foreigners, brought, fulda, attaching, recognize,
# Nearest to not: generalizations, contributors, socially, order, severity, adapt, thirds, particulars,
# Nearest to d: painter, vechten, hicks, recipient, scientist, laureate, belli, composer,
# Nearest to he: herself, his, formulation, incorruptible, callejas, spearman, hotel, juba,
# Nearest to nobel: recipient, sgh, poet, geneticist, one, prize, getz, blondes,
# Nearest to event: tonight, harker, parrot, anthropology, ranked, violence, sunday, bronte,
# Nearest to dr: feb, fanon, cooh, palais, auguste, fielders, disruptive, novella,
# Nearest to lived: exptime, fainter, attalus, lord, emerged, neue, orsz, flo,
# Nearest to rise: superluminal, barre, hacienda, maura, mismanaged, pretends, insubordination, benthic,
# Nearest to arts: modern, painting, subtler, school, architecture, art, lane, kata,
# Nearest to shown: wcs, symmetric, baran, troas, kda, runes, plastics, thrown,
# Nearest to account: reprisals, tars, affirm, formulaic, mansur, titus, automaticity, retrieves,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2401 0.0301 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2251 0.0290 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2290 0.0289 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1460 0.0291 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1983 0.0290 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1734 0.0290 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1470 0.0288 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1955 0.0290 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2070 0.0291 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1676 0.0289 sec/batch
# Nearest to between: extend, inquisitors, arterial, which, slovenians, conclude, submissive, contends,
# Nearest to at: outflow, lindy, upstate, cropped, nineteen, profiles, civilians, hysteria,
# Nearest to into: from, frente, yoreh, lax, cordell, ages, athabaskan, blu,
# Nearest to has: brownstone, hetero, pon, crm, resolution, hmac, actors, portmanteaus,
# Nearest to but: healthier, ultimate, wasn, fulda, evident, stabilizer, packed, brought,
# Nearest to not: generalizations, contributors, severity, order, socially, thirds, with, particulars,
# Nearest to d: vechten, painter, nokia, hicks, belli, gorta, brightness, manzarek,
# Nearest to he: his, incorruptible, herself, formulation, spearman, blackadder, juba, hotel,
# Nearest to nobel: sgh, recipient, geneticist, poet, getz, thiele, blondes, prize,
# Nearest to event: tonight, parrot, bunge, anthropology, harker, compete, ranked, each,
# Nearest to dr: feb, fanon, palais, novella, auguste, portrayals, fielders, cooh,
# Nearest to lived: fainter, attalus, exptime, neue, emerged, lord, orsz, flo,
# Nearest to rise: superluminal, maura, pretends, mismanaged, stakeholder, barre, cvbgs, canidae,
# Nearest to arts: modern, school, painting, architecture, landmarks, art, undergraduate, kata,
# Nearest to shown: wcs, baran, kda, troas, symmetric, runes, thrown, keystone,
# Nearest to account: reprisals, tars, affirm, mansur, formulaic, titus, dicotyledonous, retrieves,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1685 0.0301 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2322 0.0291 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1742 0.0290 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1536 0.0288 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2079 0.0289 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1873 0.0290 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1808 0.0289 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1493 0.0290 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1391 0.0289 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1575 0.0289 sec/batch
# Nearest to between: extend, arterial, inquisitors, submissive, eco, slovenians, constructions, which,
# Nearest to at: outflow, lindy, nineteen, upstate, cropped, profiles, scuola, sistine,
# Nearest to into: from, yoreh, lax, infernal, frente, cordell, clot, kohoutek,
# Nearest to has: brownstone, hetero, resolution, crm, pon, portmanteaus, actors, geographical,
# Nearest to but: healthier, wasn, ultimate, evident, fulda, gaia, recognize, packed,
# Nearest to not: generalizations, order, with, contributors, particulars, tokens, clarifies, socially,
# Nearest to d: painter, vechten, hicks, laureate, belli, nokia, scientist, recipient,
# Nearest to he: his, herself, formulation, incorruptible, spearman, hotel, blackadder, callejas,
# Nearest to nobel: recipient, sgh, geneticist, poet, physiology, one, thiele, prize,
# Nearest to event: tonight, parrot, each, compete, anthropology, gwp, ranked, bunge,
# Nearest to dr: feb, fanon, novella, palais, portrayals, fielders, cooh, auguste,
# Nearest to lived: attalus, fainter, exptime, lord, orsz, neue, emerged, masque,
# Nearest to rise: superluminal, insubordination, cvbgs, hacienda, maura, pretends, barre, stakeholder,
# Nearest to arts: modern, school, painting, landmarks, art, architecture, undergraduate, kata,
# Nearest to shown: wcs, troas, kda, baran, symmetric, runes, bluebirds, keystone,
# Nearest to account: reprisals, affirm, titus, tars, mansur, convincing, formulaic, dicotyledonous,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1978 0.0300 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1656 0.0290 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1941 0.0291 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1945 0.0291 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1397 0.0291 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1360 0.0288 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1626 0.0290 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1152 0.0292 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1789 0.0290 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2113 0.0291 sec/batch
# Nearest to between: extend, inquisitors, slovenians, arterial, conclude, pannonia, contends, assembleia,
# Nearest to at: upstate, apostate, cropped, civilians, lindy, outflow, scuola, profiles,
# Nearest to into: yoreh, lax, infernal, cordell, from, repubblica, kohoutek, frente,
# Nearest to has: brownstone, crm, resolution, pon, actors, portmanteaus, geographical, hetero,
# Nearest to but: healthier, wasn, ultimate, fulda, gaia, evident, brought, recognize,
# Nearest to not: generalizations, socially, clarifies, with, contributors, order, thirds, deceitful,
# Nearest to d: painter, hicks, vechten, scientist, belli, botanist, recipient, laureate,
# Nearest to he: his, formulation, incorruptible, spearman, herself, hotel, callejas, avram,
# Nearest to nobel: recipient, geneticist, sgh, poet, one, physiology, prize, getz,
# Nearest to event: tonight, parrot, ranked, anthropology, gwp, each, compete, harker,
# Nearest to dr: feb, fanon, novella, portrayals, palais, auguste, storyline, scholes,
# Nearest to lived: attalus, fainter, exptime, orsz, neue, gah, lord, separated,
# Nearest to rise: insubordination, cvbgs, barre, superluminal, hacienda, maura, misread, pretends,
# Nearest to arts: modern, school, painting, art, landmarks, undergraduate, architecture, subtler,
# Nearest to shown: wcs, troas, kda, symmetric, baran, naissus, bluebirds, runes,
# Nearest to account: reprisals, affirm, titus, tars, convincing, dicotyledonous, formulaic, mansur,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2175 0.0301 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1369 0.0290 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1453 0.0289 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1741 0.0289 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0305 0.0289 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1700 0.0290 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1381 0.0289 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1365 0.0293 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1593 0.0069 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0965 0.0291 sec/batch
# Nearest to between: extend, inquisitors, arterial, slovenians, eco, pole, dispute, which,
# Nearest to at: outflow, upstate, cropped, lindy, rushed, photovoltaic, revitalize, profiles,
# Nearest to into: yoreh, from, infernal, lax, frente, cordell, exact, kohoutek,
# Nearest to has: brownstone, crm, actors, pon, geographical, hmac, libyans, portmanteaus,
# Nearest to but: healthier, wasn, ultimate, gaia, evident, attaching, way, stabilizer,
# Nearest to not: generalizations, clarifies, with, socially, expand, order, thirds, positioned,
# Nearest to d: painter, vechten, hicks, belli, botanist, scientist, illustrator, roche,
# Nearest to he: formulation, his, herself, incorruptible, hotel, penicillin, tired, callejas,
# Nearest to nobel: recipient, geneticist, sgh, prize, poet, physiology, getz, one,
# Nearest to event: tonight, parrot, anthropology, gwp, ranked, each, clash, wtc,
# Nearest to dr: feb, fanon, palais, portrayals, fielders, cooh, novella, modernised,
# Nearest to lived: attalus, fainter, exptime, orsz, neue, gah, hunters, emerged,
# Nearest to rise: insubordination, superluminal, cvbgs, barre, misread, maura, confederate, stakeholder,
# Nearest to arts: modern, painting, art, undergraduate, school, landmarks, architecture, kata,
# Nearest to shown: wcs, troas, kda, baran, symmetric, naissus, bluebirds, runes,
# Nearest to account: reprisals, affirm, tars, titus, formulaic, jurassic, dicotyledonous, mansur,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0936 0.0300 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0919 0.0291 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1047 0.0290 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0620 0.0289 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0795 0.0290 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0352 0.0289 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0900 0.0289 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1086 0.0288 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1233 0.0291 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0005 0.0289 sec/batch
# Nearest to between: extend, inquisitors, arterial, slovenians, dispute, conclude, boundary, pole,
# Nearest to at: outflow, photovoltaic, upstate, cropped, civilians, orbital, lindy, vestibule,
# Nearest to into: yoreh, from, frente, infernal, lax, kohoutek, mutiny, ages,
# Nearest to has: brownstone, actors, pon, geographical, crm, libyans, hmac, jur,
# Nearest to but: healthier, gaia, wasn, evident, stabilizer, ultimate, packed, fulda,
# Nearest to not: with, order, generalizations, clarifies, contributors, plagiarism, socially, severity,
# Nearest to d: painter, vechten, hicks, botanist, belli, nokia, manzarek, scientist,
# Nearest to he: his, hotel, hence, incorruptible, penicillin, formulation, herself, tired,
# Nearest to nobel: recipient, geneticist, sgh, prize, physiology, poet, getz, blondes,
# Nearest to event: tonight, parrot, gwp, anthropology, ranked, each, negroids, nap,
# Nearest to dr: feb, fanon, aspartic, fielders, cooh, captions, portrayals, novella,
# Nearest to lived: attalus, fainter, exptime, orsz, neue, gah, separated, emerged,
# Nearest to rise: misread, insubordination, superluminal, cvbgs, barre, maura, stakeholder, agates,
# Nearest to arts: modern, painting, school, art, undergraduate, landmarks, architecture, kata,
# Nearest to shown: wcs, kda, troas, baran, symmetric, bluebirds, runes, mystery,
# Nearest to account: reprisals, affirm, titus, mansur, sira, dicotyledonous, jurassic, convincing,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0290 0.0300 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0533 0.0289 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9996 0.0289 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0525 0.0289 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0852 0.0290 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0586 0.0288 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0631 0.0289 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1112 0.0289 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0565 0.0293 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0528 0.0288 sec/batch
# Nearest to between: extend, arterial, dispute, inquisitors, slovenians, conclude, pole, stages,
# Nearest to at: cropped, outflow, upstate, photovoltaic, marys, lindy, profiles, coronal,
# Nearest to into: yoreh, infernal, from, lax, kohoutek, clot, frente, bracket,
# Nearest to has: actors, crm, geographical, brownstone, of, the, hmac, that,
# Nearest to but: healthier, evident, stabilizer, ultimate, fulda, gaia, wasn, attaching,
# Nearest to not: generalizations, with, contributors, plagiarism, order, fair, severity, particulars,
# Nearest to d: vechten, painter, nokia, belli, botanist, hicks, manzarek, roche,
# Nearest to he: his, hotel, spearman, incorruptible, formulation, herself, penicillin, saddle,
# Nearest to nobel: recipient, geneticist, sgh, prize, physiology, poet, getz, thiele,
# Nearest to event: tonight, each, gwp, anthropology, nap, ranked, negroids, propagate,
# Nearest to dr: feb, fielders, fanon, novella, portrayals, captions, cooh, palais,
# Nearest to lived: attalus, fainter, exptime, neue, orsz, gah, crests, masque,
# Nearest to rise: insubordination, superluminal, cvbgs, barre, misread, clanking, hezarfen, stakeholder,
# Nearest to arts: undergraduate, modern, school, art, landmarks, painting, architecture, kata,
# Nearest to shown: wcs, kda, troas, bluebirds, baran, runes, symmetric, minesweeper,
# Nearest to account: reprisals, dicotyledonous, tars, affirm, atoms, convincing, jurassic, sira,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0652 0.0300 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0744 0.0291 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0762 0.0290 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0674 0.0289 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0561 0.0290 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0400 0.0290 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0672 0.0288 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0732 0.0291 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0707 0.0291 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0686 0.0290 sec/batch
# Nearest to between: dispute, inquisitors, extend, slovenians, conclude, arterial, stages, vistula,
# Nearest to at: upstate, outflow, cropped, epicurean, nineteen, profiles, marys, praetorian,
# Nearest to into: yoreh, from, frente, infernal, lax, plantagenet, cordell, mutiny,
# Nearest to has: actors, geographical, pon, brownstone, portmanteaus, crm, hmac, ogre,
# Nearest to but: healthier, fulda, gaia, evident, brought, ultimate, wasn, ephesus,
# Nearest to not: generalizations, with, clarifies, contributors, fair, plagiarism, particulars, order,
# Nearest to d: vechten, painter, nokia, botanist, manzarek, hicks, belli, tra,
# Nearest to he: his, formulation, hence, spearman, hotel, attended, penicillin, incorruptible,
# Nearest to nobel: recipient, geneticist, sgh, prize, physiology, thiele, getz, blondes,
# Nearest to event: tonight, gwp, anthropology, each, ranked, parrot, negroids, clash,
# Nearest to dr: feb, portrayals, fanon, captions, fielders, novella, palais, sojourner,
# Nearest to lived: attalus, fainter, orsz, crests, gah, exptime, houses, neue,
# Nearest to rise: insubordination, misread, cvbgs, barre, clanking, christendom, superluminal, eugenicist,
# Nearest to arts: undergraduate, art, school, painting, landmarks, modern, architecture, kata,
# Nearest to shown: wcs, kda, troas, runes, bluebirds, minesweeper, baran, symmetric,
# Nearest to account: reprisals, dicotyledonous, titus, sira, convincing, affirm, jurassic, mansur,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0756 0.0299 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0111 0.0288 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0188 0.0289 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0442 0.0290 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0866 0.0290 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0984 0.0290 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1251 0.0289 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0304 0.0290 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0083 0.0290 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0568 0.0289 sec/batch
# Nearest to between: dispute, slovenians, extend, arterial, inquisitors, conclude, vistula, boundary,
# Nearest to at: upstate, cropped, outflow, lindy, apostate, marys, rushed, revitalize,
# Nearest to into: yoreh, infernal, mutiny, from, kohoutek, clot, lax, crossings,
# Nearest to has: pon, geographical, actors, brownstone, libyans, crm, tend, portmanteaus,
# Nearest to but: healthier, wasn, evident, gaia, attaching, brought, fulda, stabilizer,
# Nearest to not: generalizations, clarifies, with, severity, contributors, fair, thirds, withholding,
# Nearest to d: painter, vechten, botanist, belli, knudsen, hicks, gorta, tra,
# Nearest to he: his, callejas, formulation, spearman, attended, penicillin, hotel, hence,
# Nearest to nobel: recipient, geneticist, sgh, prize, physiology, getz, blondes, poet,
# Nearest to event: tonight, gwp, ranked, anthropology, wtc, parrot, each, lepanto,
# Nearest to dr: feb, portrayals, captions, fanon, fielders, signage, sojourner, palais,
# Nearest to lived: attalus, fainter, orsz, exptime, houses, gah, crests, neue,
# Nearest to rise: insubordination, cvbgs, misread, barre, superluminal, hezarfen, clanking, chayefsky,
# Nearest to arts: undergraduate, art, school, modern, landmarks, painting, kata, architecture,
# Nearest to shown: wcs, troas, kda, runes, bluebirds, baran, mystery, naissus,
# Nearest to account: titus, sira, dicotyledonous, reprisals, convincing, mansur, jurassic, affirm,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9589 0.0300 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0257 0.0291 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0644 0.0289 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0498 0.0290 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0739 0.0289 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0203 0.0284 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9936 0.0291 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9924 0.0292 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0274 0.0290 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9762 0.0291 sec/batch
# Nearest to between: arterial, slovenians, dispute, extend, vistula, inquisitors, fusion, stages,
# Nearest to at: upstate, apostate, cropped, rushed, to, outflow, vestibule, wounded,
# Nearest to into: yoreh, from, infernal, lax, kohoutek, clot, repubblica, crossings,
# Nearest to has: brownstone, pon, geographical, actors, libyans, portmanteaus, tend, parklands,
# Nearest to but: healthier, gaia, wasn, fulda, ultimate, attaching, brought, evident,
# Nearest to not: with, clarifies, plagiarism, generalizations, doesn, existential, fair, shambles,
# Nearest to d: vechten, painter, botanist, knudsen, dickie, roeg, belli, mcneill,
# Nearest to he: his, formulation, hence, penicillin, incorruptible, attended, pilate, manchus,
# Nearest to nobel: recipient, prize, geneticist, sgh, physiology, getz, blondes, specializing,
# Nearest to event: tonight, gwp, wtc, ranked, nap, parrot, anthropology, lepanto,
# Nearest to dr: feb, fanon, portrayals, captions, fielders, aspartic, signage, cermak,
# Nearest to lived: attalus, fainter, exptime, orsz, houses, crests, gah, neue,
# Nearest to rise: insubordination, misread, cvbgs, barre, superluminal, clanking, christendom, hezarfen,
# Nearest to arts: art, undergraduate, kata, school, painting, modern, landmarks, architecture,
# Nearest to shown: wcs, kda, troas, mystery, baran, runes, bluebirds, minesweeper,
# Nearest to account: titus, convincing, sira, reprisals, dicotyledonous, mansur, affirm, jurassic,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9909 0.0301 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9402 0.0291 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0169 0.0288 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0057 0.0289 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0447 0.0289 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0069 0.0289 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9286 0.0290 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9582 0.0289 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9302 0.0290 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9794 0.0291 sec/batch
# Nearest to between: arterial, slovenians, dispute, extend, inquisitors, vistula, which, conclude,
# Nearest to at: upstate, rushed, cropped, revitalize, outflow, to, apostate, vestibule,
# Nearest to into: yoreh, from, mutiny, clot, lax, frente, kohoutek, plantagenet,
# Nearest to has: geographical, the, pon, brownstone, of, libyans, actors, tend,
# Nearest to but: healthier, gaia, evident, ultimate, brought, fulda, third, wasn,
# Nearest to not: with, generalizations, clarifies, fair, does, existential, doesn, thirds,
# Nearest to d: vechten, nokia, knudsen, manzarek, janszoon, tra, gorta, roche,
# Nearest to he: his, attended, hence, formulation, incorruptible, tired, pilate, penicillin,
# Nearest to nobel: recipient, geneticist, prize, sgh, physiology, specializing, blondes, getz,
# Nearest to event: tonight, gwp, nap, wtc, ranked, each, compete, parrot,
# Nearest to dr: feb, fanon, aspartic, fielders, signage, captions, portrayals, cermak,
# Nearest to lived: attalus, fainter, crests, gah, orsz, houses, exptime, separated,
# Nearest to rise: misread, insubordination, cvbgs, superluminal, barre, clanking, christendom, hezarfen,
# Nearest to arts: undergraduate, art, school, kata, painting, landmarks, modern, architecture,
# Nearest to shown: wcs, kda, mystery, minesweeper, baran, troas, symmetric, bluebirds,
# Nearest to account: titus, convincing, dicotyledonous, sira, mansur, reprisals, inflationary, jurassic,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0003 0.0299 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9556 0.0289 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9742 0.0289 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0108 0.0290 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0001 0.0289 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9806 0.0290 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9844 0.0290 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9877 0.0290 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0001 0.0291 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9871 0.0288 sec/batch
# Nearest to between: arterial, dispute, slovenians, extend, vistula, leyden, inquisitors, conclude,
# Nearest to at: upstate, cropped, apostate, revitalize, rushed, lindy, nineteen, stride,
# Nearest to into: yoreh, bracket, kohoutek, infernal, sketch, mutiny, repubblica, clot,
# Nearest to has: actors, pon, brownstone, geographical, that, the, compromising, cynical,
# Nearest to but: healthier, ultimate, third, evident, wasn, gaia, stabilizer, vocalised,
# Nearest to not: with, generalizations, clarifies, fair, does, plagiarism, that, deceitful,
# Nearest to d: vechten, knudsen, painter, botanist, roche, scientist, manzarek, janszoon,
# Nearest to he: his, incorruptible, attended, pilate, formulation, hence, spearman, callejas,
# Nearest to nobel: recipient, prize, geneticist, sgh, physiology, blondes, getz, poet,
# Nearest to event: tonight, gwp, nap, each, compete, ranked, propagate, wtc,
# Nearest to dr: feb, portrayals, signage, fanon, cermak, fielders, aspartic, storyline,
# Nearest to lived: attalus, fainter, gah, crests, orsz, houses, neue, exptime,
# Nearest to rise: misread, insubordination, cvbgs, barre, hezarfen, superluminal, christendom, avant,
# Nearest to arts: undergraduate, art, kata, school, modern, painting, landmarks, revival,
# Nearest to shown: wcs, kda, mystery, baran, minesweeper, runes, bluebirds, symmetric,
# Nearest to account: convincing, titus, dicotyledonous, sira, inflationary, reprisals, jurassic, mansur,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9834 0.0302 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9889 0.0290 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9962 0.0288 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9890 0.0289 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0084 0.0291 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0121 0.0290 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9840 0.0289 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9575 0.0290 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9682 0.0288 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0086 0.0292 sec/batch
# Nearest to between: dispute, slovenians, arterial, extend, vistula, which, various, afesd,
# Nearest to at: upstate, revitalize, apostate, outflow, rushed, epicurean, cropped, to,
# Nearest to into: yoreh, infernal, bracket, from, kohoutek, mutiny, clot, lax,
# Nearest to has: the, pon, that, actors, resolution, of, geographical, brownstone,
# Nearest to but: healthier, third, ultimate, gaia, brought, fulda, evident, condemnations,
# Nearest to not: with, clarifies, fair, does, generalizations, than, shambles, liberalize,
# Nearest to d: vechten, knudsen, painter, janszoon, botanist, roche, nokia, yuri,
# Nearest to he: his, attended, penicillin, formulation, incorruptible, pilate, callejas, spearman,
# Nearest to nobel: recipient, prize, geneticist, sgh, physiology, getz, blondes, winners,
# Nearest to event: tonight, gwp, nap, ranked, each, enforces, compete, propagate,
# Nearest to dr: portrayals, feb, signage, cermak, fanon, captions, sojourner, fielders,
# Nearest to lived: attalus, fainter, crests, houses, gah, orsz, neue, gimbutas,
# Nearest to rise: insubordination, misread, cvbgs, fishing, christendom, superluminal, barre, hezarfen,
# Nearest to arts: undergraduate, art, painting, kata, school, landmarks, revival, modern,
# Nearest to shown: wcs, kda, minesweeper, mystery, baran, symmetric, runes, troas,
# Nearest to account: convincing, titus, dicotyledonous, sira, affirm, reprisals, inflationary, mansur,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9881 0.0302 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0588 0.0290 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0606 0.0288 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0282 0.0289 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9229 0.0290 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9404 0.0288 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9880 0.0289 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.9515 0.0291 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9805 0.0289 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9871 0.0291 sec/batch
# Nearest to between: arterial, slovenians, dispute, vistula, extend, fusion, afesd, various,
# Nearest to at: upstate, revitalize, cropped, apostate, rushed, stride, to, approximately,
# Nearest to into: yoreh, bracket, infernal, kohoutek, crossings, from, clot, mutiny,
# Nearest to has: pon, the, geographical, actors, footy, of, brownstone, cynical,
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8749 0.0290 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8432 0.0289 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8332 0.0289 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8831 0.0288 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8771 0.0290 sec/batch
# Nearest to between: vistula, extend, wikiproject, ashland, plane, relationship, driest, terms,
# Nearest to at: lost, approximately, to, from, s, the, five, three,
# Nearest to into: yoreh, dpi, animaniacs, bracket, aslan, kohoutek, succeeds, which,
# Nearest to has: is, the, an, in, of, as, that, also,
# Nearest to but: third, intentions, to, these, already, enough, not, vocalised,
# Nearest to not: with, than, does, that, but, granted, is, to,
# Nearest to d: nokia, roeg, yee, agreeable, vechten, janszoon, nox, dweezil,
# Nearest to he: his, himself, was, attended, joined, him, career, tired,
# Nearest to nobel: prize, recipient, winners, physiology, geneticist, stokely, awarded, rocky,
# Nearest to event: extinction, tonight, gwp, nap, enforces, competitions, picchi, uninhabitable,
# Nearest to dr: sellers, signage, bi, terengganu, lyle, portrayals, storyline, hv,
# Nearest to lived: fainter, died, cation, keats, macrinus, stayed, berkeley, gatehouse,
# Nearest to rise: misread, boom, ctesias, superluminal, christendom, insubordination, rising, evolution,
# Nearest to arts: kata, beaux, undergraduate, practitioner, martial, thai, art, landmarks,
# Nearest to shown: mystery, superheroic, minesweeper, kda, wcs, carmilla, inroads, dlp,
# Nearest to account: convincing, sira, buyer, clp, grout, apulia, inflationary, tisha,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8116 0.0301 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8571 0.0292 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8638 0.0293 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8636 0.0291 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8667 0.0291 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8749 0.0292 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8402 0.0291 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8412 0.0289 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8646 0.0292 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8893 0.0289 sec/batch
# Nearest to between: in, vistula, various, driest, first, relationship, shtml, wikiproject,
# Nearest to at: from, approximately, five, s, three, of, the, lost,
# Nearest to into: yoreh, which, aslan, up, succeeds, kohoutek, from, ignited,
# Nearest to has: is, an, the, in, as, of, also, original,
# Nearest to but: intentions, third, vocalised, to, not, already, the, these,
# Nearest to not: than, with, does, that, but, granted, have, to,
# Nearest to d: nokia, yee, agreeable, roeg, janszoon, nox, vechten, gorta,
# Nearest to he: his, was, attended, joined, himself, returned, career, graduated,
# Nearest to nobel: prize, recipient, winners, physiology, geneticist, awarded, stokely, actinide,
# Nearest to event: extinction, tonight, gwp, enforces, picchi, nap, uninhabitable, competitions,
# Nearest to dr: sellers, signage, bi, portrayals, lyle, terengganu, hv, bancroft,
# Nearest to lived: died, fainter, cation, berkeley, stayed, macrinus, keats, collapse,
# Nearest to rise: misread, boom, ctesias, insubordination, rising, superluminal, sowed, christendom,
# Nearest to arts: kata, beaux, practitioner, undergraduate, martial, thai, art, landmarks,
# Nearest to shown: minesweeper, superheroic, dlp, lexicographers, kda, mystery, inroads, wcs,
# Nearest to account: convincing, grout, buyer, clp, sira, inflationary, apulia, dicotyledonous,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8812 0.0303 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8070 0.0290 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8337 0.0291 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8376 0.0289 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9282 0.0291 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8513 0.0290 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9532 0.0292 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9053 0.0289 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9177 0.0290 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8062 0.0290 sec/batch
# Nearest to between: in, vistula, relationship, various, first, driest, shtml, its,
# Nearest to at: approximately, s, from, to, of, five, the, in,
# Nearest to into: yoreh, aslan, dpi, which, ignited, up, kohoutek, succeeds,
# Nearest to has: is, in, of, the, an, as, also, high,
# Nearest to but: intentions, third, to, vocalised, already, insisting, these, enough,
# Nearest to not: with, than, that, does, granted, but, betrothal, alignment,
# Nearest to d: nokia, agreeable, yee, roeg, janszoon, nox, vechten, kluge,
# Nearest to he: his, was, attended, joined, himself, returned, after, graduated,
# Nearest to nobel: prize, recipient, winners, physiology, awarded, geneticist, stokely, actinide,
# Nearest to event: extinction, tonight, gwp, picchi, uninhabitable, nap, enforces, burdette,
# Nearest to dr: sellers, bi, signage, terengganu, lyle, kaist, portrayals, bancroft,
# Nearest to lived: died, stayed, collapse, berkeley, fainter, macrinus, moved, cation,
# Nearest to rise: misread, ctesias, boom, rising, insubordination, superluminal, usurping, christendom,
# Nearest to arts: kata, beaux, practitioner, art, thai, undergraduate, martial, landmarks,
# Nearest to shown: superheroic, minesweeper, mystery, dlp, lexicographers, kda, stings, carmilla,
# Nearest to account: convincing, clp, sira, buyer, grout, apulia, inverness, inflationary,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7857 0.0298 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8671 0.0288 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8289 0.0289 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8629 0.0290 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8497 0.0290 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8685 0.0289 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8557 0.0197 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8345 0.0289 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8255 0.0289 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8863 0.0288 sec/batch
# Nearest to between: vistula, in, relationship, driest, first, ashland, extend, various,
# Nearest to at: of, approximately, to, s, the, an, from, in,
# Nearest to into: yoreh, aslan, which, ignited, from, up, of, then,
# Nearest to has: is, an, also, the, as, in, high, have,
# Nearest to but: to, already, third, the, be, brought, vocalised, enough,
# Nearest to not: with, than, that, does, granted, but, have, insisting,
# Nearest to d: nokia, agreeable, roeg, nox, inventor, shigeru, niclas, writer,
# Nearest to he: his, was, himself, attended, joined, him, returned, after,
# Nearest to nobel: prize, recipient, winners, physiology, awarded, geneticist, stokely, chemist,
# Nearest to event: extinction, tonight, gwp, picchi, nap, uninhabitable, at, enforces,
# Nearest to dr: sellers, signage, terengganu, bi, lyle, impasse, bancroft, prescriptive,
# Nearest to lived: died, collapse, keats, fainter, stayed, moved, macrinus, berkeley,
# Nearest to rise: ctesias, misread, insubordination, superluminal, rising, boom, christendom, usurping,
# Nearest to arts: kata, beaux, practitioner, martial, art, thai, undergraduate, landmarks,
# Nearest to shown: mystery, minesweeper, dlp, superheroic, kda, inroads, stings, lexicographers,
# Nearest to account: convincing, sira, buyer, grout, clp, apulia, inverness, gaia,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8324 0.0300 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8424 0.0288 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7892 0.0288 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8106 0.0289 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8581 0.0289 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8056 0.0290 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8673 0.0290 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7415 0.0290 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8292 0.0288 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8000 0.0293 sec/batch
# Nearest to between: first, in, with, vistula, various, extend, relationship, terms,
# Nearest to at: approximately, s, an, from, to, the, of, lost,
# Nearest to into: yoreh, which, aslan, ignited, up, enzyme, from, then,
# Nearest to has: is, the, of, an, in, also, have, as,
# Nearest to but: third, the, to, these, already, not, be, enough,
# Nearest to not: with, than, that, does, granted, to, but, be,
# Nearest to d: nokia, agreeable, nox, ack, yee, janszoon, roeg, naseby,
# Nearest to he: his, was, himself, attended, joined, returned, graduating, career,
# Nearest to nobel: prize, recipient, winners, physiology, awarded, geneticist, stokely, actinide,
# Nearest to event: extinction, tonight, gwp, picchi, nap, uninhabitable, enforces, competitions,
# Nearest to dr: sellers, terengganu, bi, signage, lyle, impasse, prescriptive, klaus,
# Nearest to lived: died, fainter, cation, stayed, keats, collapse, macrinus, stucco,
# Nearest to rise: misread, ctesias, superluminal, insubordination, rising, christendom, boom, sowed,
# Nearest to arts: kata, beaux, undergraduate, art, martial, practitioner, thai, landmarks,
# Nearest to shown: mystery, minesweeper, superheroic, dlp, inroads, kda, stings, another,
# Nearest to account: convincing, buyer, clp, sira, grout, apulia, inflationary, niles,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7509 0.0299 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8413 0.0289 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8673 0.0288 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8159 0.0288 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8282 0.0289 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9060 0.0290 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8300 0.0290 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8058 0.0288 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8471 0.0289 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8369 0.0289 sec/batch
# Nearest to between: relationship, vistula, first, various, ashland, driest, terms, extend,
# Nearest to at: s, approximately, the, lost, to, an, from, of,
# Nearest to into: yoreh, up, which, ignited, aslan, enzyme, from, and,
# Nearest to has: is, the, an, have, in, of, as, also,
# Nearest to but: to, not, already, third, the, enough, be, intentions,
# Nearest to not: with, that, than, but, does, granted, be, to,
# Nearest to d: nokia, agreeable, yee, nox, roeg, vechten, kluge, ack,
# Nearest to he: his, himself, was, attended, returned, career, him, after,
# Nearest to nobel: prize, recipient, winners, physiology, awarded, geneticist, actinide, stokely,
# Nearest to event: extinction, gwp, tonight, picchi, nap, uninhabitable, competitions, enforces,
# Nearest to dr: sellers, lyle, bi, terengganu, signage, bizkit, portrayals, hv,
# Nearest to lived: died, keats, fainter, stayed, cation, macrinus, starkly, antlers,
# Nearest to rise: misread, superluminal, boom, insubordination, ctesias, rising, christendom, sowed,
# Nearest to arts: kata, beaux, art, practitioner, undergraduate, martial, thai, landmarks,
# Nearest to shown: minesweeper, superheroic, mystery, lexicographers, kda, stings, dlp, inroads,
# Nearest to account: convincing, clp, buyer, sira, grout, apulia, niles, financi,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8483 0.0299 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8519 0.0290 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8050 0.0289 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8024 0.0290 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8567 0.0289 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8570 0.0291 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8284 0.0290 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8459 0.0291 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7906 0.0289 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8234 0.0287 sec/batch
# Nearest to between: in, vistula, with, relationship, first, various, the, either,
# Nearest to at: the, s, an, approximately, from, zero, lost, to,
# Nearest to into: yoreh, which, up, to, aslan, from, ignited, succeeds,
# Nearest to has: is, an, the, in, of, have, also, as,
# Nearest to but: is, to, not, be, the, already, these, third,
# Nearest to not: with, than, that, be, does, but, to, have,
# Nearest to d: nokia, agreeable, yee, nox, ack, gorta, tra, janszoon,
# Nearest to he: his, was, returned, joined, attended, himself, him, career,
# Nearest to nobel: prize, recipient, winners, physiology, awarded, actinide, geneticist, stokely,
# Nearest to event: extinction, gwp, tonight, picchi, competitions, uninhabitable, nap, enforces,
# Nearest to dr: sellers, bi, terengganu, lyle, signage, brethren, hv, klaus,
# Nearest to lived: died, stayed, fainter, collapse, keats, cation, orphanage, stucco,
# Nearest to rise: misread, ctesias, insubordination, boom, superluminal, rising, christendom, cossiga,
# Nearest to arts: kata, beaux, art, undergraduate, practitioner, martial, thai, landmarks,
# Nearest to shown: minesweeper, stings, dlp, mystery, lexicographers, superheroic, kda, inroads,
# Nearest to account: convincing, buyer, clp, sira, grout, apulia, gaia, geocache,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8565 0.0300 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8196 0.0290 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9486 0.0290 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9009 0.0289 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8926 0.0289 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7736 0.0288 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7799 0.0289 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8637 0.0290 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7457 0.0289 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8445 0.0289 sec/batch
# Nearest to between: relationship, in, with, vistula, various, of, first, either,
# Nearest to at: s, an, from, approximately, to, the, lost, zero,
# Nearest to into: yoreh, which, up, aslan, ignited, dpi, then, succeeds,
# Nearest to has: is, of, the, an, in, also, to, as,
# Nearest to but: to, not, already, enough, third, be, evident, vocalised,
# Nearest to not: with, than, that, does, be, but, to, granted,
# Nearest to d: agreeable, nokia, writer, roeg, inventor, poet, kluge, vechten,
# Nearest to he: his, was, attended, himself, joined, returned, him, career,
# Nearest to nobel: prize, recipient, physiology, winners, awarded, stokely, geneticist, actinide,
# Nearest to event: extinction, tonight, gwp, picchi, fincher, uninhabitable, enforces, competitions,
# Nearest to dr: sellers, terengganu, bi, lyle, kaist, brethren, impasse, signage,
# Nearest to lived: died, stayed, collapse, keats, fainter, moved, orphanage, macrinus,
# Nearest to rise: misread, boom, superluminal, insubordination, ctesias, rising, usurping, christendom,
# Nearest to arts: kata, beaux, practitioner, martial, thai, art, undergraduate, inversional,
# Nearest to shown: stings, mystery, superheroic, carmilla, dlp, kda, psychiatrists, lexicographers,
# Nearest to account: convincing, buyer, clp, sira, grout, geocache, gaia, apulia,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8355 0.0300 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8248 0.0288 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
